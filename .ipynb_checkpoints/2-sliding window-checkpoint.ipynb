# %% [markdown]
# So, based on previous analysis we are seeing something at 2..4 second intervals.
# Now, let's repeat eveything - doing the splits, and scanning with a 2..4 sliding windows over test and control.
#
# possible metrics:
#
# 1) directional change p>0.5 == p>0.5
# 2) z-score metric: (p1-0.5) (exp 0) + (p2-0.5) (exp 0)
# 3) moments of p (low and high) -> I would need a vector of Ps with a sliding windows for 2 (test + control) x amount of windsor splits

# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from scipy.stats import chi2, binom
import gzip
from tqdm.notebook import trange, tqdm
import glob
import random
import seaborn as sns
from joblib import Parallel, delayed
import scipy as sp
from statsmodels.stats.proportion import proportion_confint

# %%
data = pd.read_parquet('data2019.parquet')

# %%
data_std = data.std(axis=0)[3:]

# %%
data -= 100

# %%
#     if use_real_std:
#         STD_200_FLIPS = data_std
#     else:
#         STD_200_FLIPS = math.sqrt(200)/2

data.iloc[3:] /= data_std

# %%
nans = data.iloc[3:].isna().sum(axis=1)
sqrts = np.sqrt(data.iloc[3:].shape[1]-nans)
z_norm_data = (data.iloc[3:]).sum(axis=1)/sqrts

# %%
def zscore_to_proba_vector(seq, window, mode='full'):
    return stats.chi2.sf(np.convolve(seq**2,np.ones(window),mode),window)

# %%
print(np.nanmean(zscore_to_proba_vector(z_norm_data,1)),
      np.nanmean(zscore_to_proba_vector(z_norm_data,2)),
      np.nanmean(zscore_to_proba_vector(z_norm_data,3)))
# Out:
# 0.5000064265188391 0.49995459005770176 0.49996140027177627

# %%
eggs = set(data.columns[3:])
         
    
test_eggs = list(random.sample(eggs,len(eggs)//2))
control_eggs = list(set(eggs) - set(test_eggs))

assert set(test_eggs) - set(control_eggs) == set(test_eggs)

test_data = data[test_eggs]
test_nans = test_data.isna().sum(axis=1)
sqrts = np.sqrt(test_data.shape[1]-test_nans)
z_norm_test = (test_data).sum(axis=1)/sqrts


control_data = data[control_eggs]
control_nans = control_data.isna().sum(axis=1)
sqrts = np.sqrt(control_data.shape[1]-control_nans)
z_norm_control = (control_data).sum(axis=1)/sqrts

# %%
def make_a_data_split(data, use_real_std=False):
    eggs = set(data.columns[3:])
         
    
    test_eggs = list(random.sample(eggs,len(eggs)//2))
    control_eggs = list(set(eggs) - set(test_eggs))

    assert set(test_eggs) - set(control_eggs) == set(test_eggs)

    test_data = data[test_eggs]
    test_nans = test_data.isna().sum(axis=1)
    sqrts = np.sqrt(test_data.shape[1]-test_nans)
    z_norm_test = (test_data).sum(axis=1)/sqrts


    control_data = data[control_eggs]
    control_nans = control_data.isna().sum(axis=1)
    sqrts = np.sqrt(control_data.shape[1]-control_nans)
    z_norm_control = (control_data).sum(axis=1)/sqrts
    
    return z_norm_test, z_norm_control, test_nans, control_nans

# %%
test, control, test_nans, control_nans = make_a_data_split(data)

# %%
def make_run(thr, window):
    test, control, test_nans, control_nans = make_a_data_split(data)
    test_nans = test_nans[2:-2]
    
    control_nans = control_nans[2:-2]
    test_probas = zscore_to_proba_vector(test, window, mode='same')[2:-2]

    control_probas = zscore_to_proba_vector(control, window, mode='same')[2:-2]
    random_mask_for_control = np.random.binomial(1, thr, len(control_probas)).astype(bool)
    random_mask_for_test = np.random.binomial(1, thr, len(test_probas)).astype(bool)

    return {'direct_mean': np.nanmean(control_probas[test_probas<thr]),
            'direct_counts': (test_probas<thr).sum(),
            'direct_nans': control_nans.iloc[test_probas<thr].mean(),

            'random_direct_mean': np.nanmean(control_probas[random_mask_for_control]),
            'random_direct_counts': (random_mask_for_control).sum(),
            'random_direct_nans': control_nans.iloc[random_mask_for_control].mean(),

            'inverted_mean': np.nanmean(test_probas[control_probas<thr]),
            'inverted_counts': (control_probas<thr).sum(),
            'inverted_nans': test_nans.iloc[control_probas<thr].mean(),

            'random_inverted_mean': np.nanmean(test_probas[random_mask_for_test]),
            'random_inverted_counts': (random_mask_for_test).sum(),
            'random_inverted_nans': test_nans.iloc[random_mask_for_test].mean(),

            'window': window,
            'thr': thr}

# %%
make_run(0.01, 2)
# Out:
# {'direct_mean': 0.4996767119548327,
#  'direct_counts': 311847,
#  'direct_nans': 3.863166873498863,
#  'random_direct_mean': 0.5002451201435328,
#  'random_direct_counts': 311983,
#  'random_direct_nans': 3.859197456271656,
#  'inverted_mean': 0.500682265498198,
#  'inverted_counts': 313597,
#  'inverted_nans': 1.7222486184497938,
#  'random_inverted_mean': 0.5004321219194839,
#  'random_inverted_counts': 311876,
#  'random_inverted_nans': 1.7180706434608626,
#  'window': 2,
#  'thr': 0.01}

# %%
results = []
with tqdm(total=5*2) as pbar:
    for thr in [0.01,0.0075,0.005,0.0025,0.001]:
        for window in [2,3]:
            partial_results = Parallel(n_jobs=4, prefer="threads")(delayed(make_run)(thr, window) for i in range(32))
            results.append(partial_results)
            pbar.update(1)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
def flatten(t):
    return [item for sublist in t for item in sublist]
# Out:
# [[{'direct_mean': 0.500395699333494,
#    'direct_counts': 313197,
#    'direct_nans': 3.9990708723263633,
#    'random_direct_mean': 0.5004389011394909,
#    'random_direct_counts': 312361,
#    'random_direct_nans': 3.998671409042742,
#    'inverted_mean': 0.49963400841077443,
#    'inverted_counts': 313971,
#    'inverted_nans': 1.5744989186899427,
#    'random_inverted_mean': 0.5006064036914434,
#    'random_inverted_counts': 312067,
#    'random_inverted_nans': 1.577302310080848,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5004304211147799,
#    'direct_counts': 313421,
#    'direct_nans': 2.8168246543786153,
#    'random_direct_mean': 0.5004179916497185,
#    'random_direct_counts': 314199,
#    'random_direct_nans': 2.8157123351761144,
#    'inverted_mean': 0.5006277215291691,
#    'inverted_counts': 312328,
#    'inverted_nans': 2.75500435439666,
#    'random_inverted_mean': 0.5004053782177207,
#    'random_inverted_counts': 313007,
#    'random_inverted_nans': 2.757781774848486,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5006255250876187,
#    'direct_counts': 311300,
#    'direct_nans': 4.6471956312239,
#    'random_direct_mean': 0.5009544088679065,
#    'random_direct_counts': 313887,
#    'random_direct_nans': 4.649125322170081,
#    'inverted_mean': 0.5006482887518946,
#    'inverted_counts': 312987,
#    'inverted_nans': 0.92880854476384,
#    'random_inverted_mean': 0.4997865629776045,
#    'random_inverted_counts': 312781,
#    'random_inverted_nans': 0.9304145712175612,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5003507975643914,
#    'direct_counts': 312969,
#    'direct_nans': 3.06957877617272,
#    'random_direct_mean': 0.4995735737736299,
#    'random_direct_counts': 313781,
#    'random_direct_nans': 3.0701157813889304,
#    'inverted_mean': 0.5010547258048139,
#    'inverted_counts': 311975,
#    'inverted_nans': 2.509479926276144,
#    'random_inverted_mean': 0.4999285242170332,
#    'random_inverted_counts': 312231,
#    'random_inverted_nans': 2.508777155375347,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5011743109898871,
#    'direct_counts': 314178,
#    'direct_nans': 2.7259260673885506,
#    'random_direct_mean': 0.4999382387611552,
#    'random_direct_counts': 312680,
#    'random_direct_nans': 2.722559805552002,
#    'inverted_mean': 0.5008133929803915,
#    'inverted_counts': 312638,
#    'inverted_nans': 2.8554174476551153,
#    'random_inverted_mean': 0.5004880650949197,
#    'random_inverted_counts': 312963,
#    'random_inverted_nans': 2.8544684195895362,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5003631874373068,
#    'direct_counts': 312882,
#    'direct_nans': 3.252842924808714,
#    'random_direct_mean': 0.49940246264585925,
#    'random_direct_counts': 313352,
#    'random_direct_nans': 3.2531785340447805,
#    'inverted_mean': 0.5001457240303054,
#    'inverted_counts': 312015,
#    'inverted_nans': 2.327086838773777,
#    'random_inverted_mean': 0.4994658924342121,
#    'random_inverted_counts': 313326,
#    'random_inverted_nans': 2.3242469504605427,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5008559968694192,
#    'direct_counts': 312575,
#    'direct_nans': 3.5621178917059906,
#    'random_direct_mean': 0.5005417159669707,
#    'random_direct_counts': 312198,
#    'random_direct_nans': 3.5604135836872755,
#    'inverted_mean': 0.5004822658850794,
#    'inverted_counts': 313589,
#    'inverted_nans': 2.017542069396567,
#    'random_inverted_mean': 0.49946091264253145,
#    'random_inverted_counts': 312991,
#    'random_inverted_nans': 2.0151505953845317,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5011494927559415,
#    'direct_counts': 313590,
#    'direct_nans': 2.477142128256641,
#    'random_direct_mean': 0.4999188250738864,
#    'random_direct_counts': 312403,
#    'random_direct_nans': 2.4745793094176434,
#    'inverted_mean': 0.5002400165262869,
#    'inverted_counts': 311018,
#    'inverted_nans': 3.1053379547164472,
#    'random_inverted_mean': 0.5000835660945041,
#    'random_inverted_counts': 313358,
#    'random_inverted_nans': 3.0987018043260424,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.49927960182767384,
#    'direct_counts': 313994,
#    'direct_nans': 1.906415409211641,
#    'random_direct_mean': 0.4998172494245824,
#    'random_direct_counts': 312592,
#    'random_direct_nans': 1.9052886830117213,
#    'inverted_mean': 0.5002392069039757,
#    'inverted_counts': 311420,
#    'inverted_nans': 3.6708271787296898,
#    'random_inverted_mean': 0.4995430518603783,
#    'random_inverted_counts': 313486,
#    'random_inverted_nans': 3.675446431419585,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.49964500565815523,
#    'direct_counts': 313863,
#    'direct_nans': 2.8552457600927794,
#    'random_direct_mean': 0.4998057609722596,
#    'random_direct_counts': 312427,
#    'random_direct_nans': 2.8594007560166053,
#    'inverted_mean': 0.500055593774159,
#    'inverted_counts': 311902,
#    'inverted_nans': 2.71996011567736,
#    'random_inverted_mean': 0.500081717228117,
#    'random_inverted_counts': 312659,
#    'random_inverted_nans': 2.7225923450148564,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5002295178743749,
#    'direct_counts': 313722,
#    'direct_nans': 3.0247289001090136,
#    'random_direct_mean': 0.49995253415093,
#    'random_direct_counts': 312765,
#    'random_direct_nans': 3.0237910252106213,
#    'inverted_mean': 0.5016032254280881,
#    'inverted_counts': 312321,
#    'inverted_nans': 2.549585202403937,
#    'random_inverted_mean': 0.4997690622864033,
#    'random_inverted_counts': 313204,
#    'random_inverted_nans': 2.5502388219818393,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.4998388369968566,
#    'direct_counts': 313139,
#    'direct_nans': 3.38655357524933,
#    'random_direct_mean': 0.5005292926203488,
#    'random_direct_counts': 311801,
#    'random_direct_nans': 3.387949365139945,
#    'inverted_mean': 0.500385657839115,
#    'inverted_counts': 313587,
#    'inverted_nans': 2.1927854152117274,
#    'random_inverted_mean': 0.5002202272487378,
#    'random_inverted_counts': 313927,
#    'random_inverted_nans': 2.19141392744173,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5007696322482236,
#    'direct_counts': 313305,
#    'direct_nans': 2.770661176808541,
#    'random_direct_mean': 0.499856571566289,
#    'random_direct_counts': 312321,
#    'random_direct_nans': 2.772333592681888,
#    'inverted_mean': 0.5007006676036019,
#    'inverted_counts': 313847,
#    'inverted_nans': 2.8083843401402593,
#    'random_inverted_mean': 0.4994394490503758,
#    'random_inverted_counts': 313307,
#    'random_inverted_nans': 2.8062922309428133,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.49985730246036625,
#    'direct_counts': 313304,
#    'direct_nans': 3.6906231647218037,
#    'random_direct_mean': 0.5003512714880824,
#    'random_direct_counts': 313031,
#    'random_direct_nans': 3.687727413578847,
#    'inverted_mean': 0.4997401082462273,
#    'inverted_counts': 313309,
#    'inverted_nans': 1.8904085104481518,
#    'random_inverted_mean': 0.5004325894118069,
#    'random_inverted_counts': 312221,
#    'random_inverted_nans': 1.8900618472171955,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.500925004266498,
#    'direct_counts': 312011,
#    'direct_nans': 3.5141517446500283,
#    'random_direct_mean': 0.5010577615059475,
#    'random_direct_counts': 313286,
#    'random_direct_nans': 3.5138659244268817,
#    'inverted_mean': 0.5008890698112858,
#    'inverted_counts': 313840,
#    'inverted_nans': 2.062560540402753,
#    'random_inverted_mean': 0.4998909925370654,
#    'random_inverted_counts': 312231,
#    'random_inverted_nans': 2.063840553948839,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5007612920453242,
#    'direct_counts': 315416,
#    'direct_nans': 2.990580693433434,
#    'random_direct_mean': 0.4987737987711366,
#    'random_direct_counts': 311868,
#    'random_direct_nans': 2.9917946054099813,
#    'inverted_mean': 0.5007413485878749,
#    'inverted_counts': 313928,
#    'inverted_nans': 2.5838217680487245,
#    'random_inverted_mean': 0.49940438999960163,
#    'random_inverted_counts': 312579,
#    'random_inverted_nans': 2.584297089695725,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5003935116378122,
#    'direct_counts': 313226,
#    'direct_nans': 3.2128048118610844,
#    'random_direct_mean': 0.5004896148103484,
#    'random_direct_counts': 312657,
#    'random_direct_nans': 3.2084904543957116,
#    'inverted_mean': 0.5014603573390948,
#    'inverted_counts': 314686,
#    'inverted_nans': 2.365430937505958,
#    'random_inverted_mean': 0.4997439157936468,
#    'random_inverted_counts': 312966,
#    'random_inverted_nans': 2.367924950314092,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.49962171033656094,
#    'direct_counts': 313773,
#    'direct_nans': 2.7155905702530174,
#    'random_direct_mean': 0.4994772165134583,
#    'random_direct_counts': 312461,
#    'random_direct_nans': 2.7127737541645196,
#    'inverted_mean': 0.5000320028463985,
#    'inverted_counts': 312035,
#    'inverted_nans': 2.862762190138927,
#    'random_inverted_mean': 0.4999578160903558,
#    'random_inverted_counts': 313272,
#    'random_inverted_nans': 2.864229806685564,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.4998227771516603,
#    'direct_counts': 313045,
#    'direct_nans': 2.6304684630005273,
#    'random_direct_mean': 0.4995756304877467,
#    'random_direct_counts': 312111,
#    'random_direct_nans': 2.630154015718767,
#    'inverted_mean': 0.50096231651584,
#    'inverted_counts': 312928,
#    'inverted_nans': 2.943082753860313,
#    'random_inverted_mean': 0.49952063744040864,
#    'random_inverted_counts': 313500,
#    'random_inverted_nans': 2.947055821371611,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5010097825044346,
#    'direct_counts': 311324,
#    'direct_nans': 3.702506070845807,
#    'random_direct_mean': 0.49960211635141966,
#    'random_direct_counts': 312885,
#    'random_direct_nans': 3.704977867267526,
#    'inverted_mean': 0.4996588659045194,
#    'inverted_counts': 314434,
#    'inverted_nans': 1.874383813455288,
#    'random_inverted_mean': 0.5002972073892937,
#    'random_inverted_counts': 312952,
#    'random_inverted_nans': 1.8691524578849152,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5011252427819403,
#    'direct_counts': 311038,
#    'direct_nans': 2.917784965181103,
#    'random_direct_mean': 0.4995420445129275,
#    'random_direct_counts': 312347,
#    'random_direct_nans': 2.921084563002046,
#    'inverted_mean': 0.5008845783930032,
#    'inverted_counts': 312671,
#    'inverted_nans': 2.6560442126068615,
#    'random_inverted_mean': 0.5002903320354098,
#    'random_inverted_counts': 312572,
#    'random_inverted_nans': 2.661063690925611,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.49963933581879527,
#    'direct_counts': 313889,
#    'direct_nans': 3.2090707224528416,
#    'random_direct_mean': 0.5001281825264506,
#    'random_direct_counts': 312370,
#    'random_direct_nans': 3.2101194096744248,
#    'inverted_mean': 0.49948171901996097,
#    'inverted_counts': 312559,
#    'inverted_nans': 2.372403290258799,
#    'random_inverted_mean': 0.49986952493382003,
#    'random_inverted_counts': 312755,
#    'random_inverted_nans': 2.372169909353967,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5007855965115798,
#    'direct_counts': 313878,
#    'direct_nans': 3.272854421144521,
#    'random_direct_mean': 0.4992345700292115,
#    'random_direct_counts': 312317,
#    'random_direct_nans': 3.27142934902679,
#    'inverted_mean': 0.5004574971280322,
#    'inverted_counts': 313301,
#    'inverted_nans': 2.307790271974874,
#    'random_inverted_mean': 0.4995689891283236,
#    'random_inverted_counts': 313438,
#    'random_inverted_nans': 2.310412266540751,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.500003606857648,
#    'direct_counts': 312666,
#    'direct_nans': 3.618522640773221,
#    'random_direct_mean': 0.5008003448165934,
#    'random_direct_counts': 313321,
#    'random_direct_nans': 3.6143092866421336,
#    'inverted_mean': 0.4999601565703563,
#    'inverted_counts': 312728,
#    'inverted_nans': 1.9655931032718528,
#    'random_inverted_mean': 0.5007822570046405,
#    'random_inverted_counts': 313522,
#    'random_inverted_nans': 1.9656929976205817,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.499733967796525,
#    'direct_counts': 312724,
#    'direct_nans': 2.4627818779498853,
#    'random_direct_mean': 0.5005669806286389,
#    'random_direct_counts': 312808,
#    'random_direct_nans': 2.459521495613923,
#    'inverted_mean': 0.5000231298162829,
#    'inverted_counts': 312783,
#    'inverted_nans': 3.122592979797495,
#    'random_inverted_mean': 0.4998815006183495,
#    'random_inverted_counts': 312989,
#    'random_inverted_nans': 3.119116007271821,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5004190929629986,
#    'direct_counts': 314618,
#    'direct_nans': 2.1603722609640896,
#    'random_direct_mean': 0.49921318185977237,
#    'random_direct_counts': 313472,
#    'random_direct_nans': 2.1576185432829726,
#    'inverted_mean': 0.5007325655770195,
#    'inverted_counts': 310964,
#    'inverted_nans': 3.425226071185089,
#    'random_inverted_mean': 0.4982161782620821,
#    'random_inverted_counts': 312403,
#    'random_inverted_nans': 3.4238211540862284,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.4995684949147172,
#    'direct_counts': 314018,
#    'direct_nans': 1.5160118209784152,
#    'random_direct_mean': 0.4999209955683854,
#    'random_direct_counts': 313687,
#    'random_direct_nans': 1.5157625276151068,
#    'inverted_mean': 0.49945476488826973,
#    'inverted_counts': 310227,
#    'inverted_nans': 4.060426719789057,
#    'random_inverted_mean': 0.4989388273322904,
#    'random_inverted_counts': 312891,
#    'random_inverted_nans': 4.061586942417647,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5008231632184846,
#    'direct_counts': 313608,
#    'direct_nans': 2.8776625596285808,
#    'random_direct_mean': 0.4998316535851943,
#    'random_direct_counts': 312773,
#    'random_direct_nans': 2.8771792961668687,
#    'inverted_mean': 0.5002771056730662,
#    'inverted_counts': 312957,
#    'inverted_nans': 2.7015852018008863,
#    'random_inverted_mean': 0.5011975586249213,
#    'random_inverted_counts': 311746,
#    'random_inverted_nans': 2.7016673830618516,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5007941462014477,
#    'direct_counts': 314219,
#    'direct_nans': 2.276606443276823,
#    'random_direct_mean': 0.4995957804270757,
#    'random_direct_counts': 312627,
#    'random_direct_nans': 2.2748642951504507,
#    'inverted_mean': 0.5008834731958572,
#    'inverted_counts': 311651,
#    'inverted_nans': 3.3024504975116398,
#    'random_inverted_mean': 0.4997609225335228,
#    'random_inverted_counts': 312970,
#    'random_inverted_nans': 3.300875483273157,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5001634907629992,
#    'direct_counts': 312296,
#    'direct_nans': 3.797739964648923,
#    'random_direct_mean': 0.4983988832325029,
#    'random_direct_counts': 312596,
#    'random_direct_nans': 3.7925629246695416,
#    'inverted_mean': 0.498963245180644,
#    'inverted_counts': 313522,
#    'inverted_nans': 1.7815878949483608,
#    'random_inverted_mean': 0.4999771018756378,
#    'random_inverted_counts': 313486,
#    'random_inverted_nans': 1.786188218931627,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.5000242116620695,
#    'direct_counts': 313128,
#    'direct_nans': 2.441701157354181,
#    'random_direct_mean': 0.4985329889120827,
#    'random_direct_counts': 312385,
#    'random_direct_nans': 2.4412439777838246,
#    'inverted_mean': 0.5006180909488553,
#    'inverted_counts': 312115,
#    'inverted_nans': 3.1404770677474647,
#    'random_inverted_mean': 0.5002105113368445,
#    'random_inverted_counts': 312970,
#    'random_inverted_nans': 3.1385659967409016,
#    'window': 2,
#    'thr': 0.01},
#   {'direct_mean': 0.49983857717340674,
#    'direct_counts': 312541,
#    'direct_nans': 2.708169488163153,
#    'random_direct_mean': 0.5008774629328945,
#    'random_direct_counts': 313343,
#    'random_direct_nans': 2.7077866746664196,
#    'inverted_mean': 0.5005630092457569,
#    'inverted_counts': 312271,
#    'inverted_nans': 2.8737378751148843,
#    'random_inverted_mean': 0.49919677358520403,
#    'random_inverted_counts': 312081,
#    'random_inverted_nans': 2.8723472431836607,
#    'window': 2,
#    'thr': 0.01}],
#  [{'direct_mean': 0.5007542186510641,
#    'direct_counts': 311879,
#    'direct_nans': 3.076372567566268,
#    'random_direct_mean': 0.5000058781601311,
#    'random_direct_counts': 313050,
#    'random_direct_nans': 3.0804663791726563,
#    'inverted_mean': 0.49988403807772935,
#    'inverted_counts': 312146,
#    'inverted_nans': 2.5001858104861188,
#    'random_inverted_mean': 0.49993767500669184,
#    'random_inverted_counts': 312121,
#    'random_inverted_nans': 2.502362865683501,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5007466864162002,
#    'direct_counts': 312044,
#    'direct_nans': 2.05492815115817,
#    'random_direct_mean': 0.4995524173424591,
#    'random_direct_counts': 313103,
#    'random_direct_nans': 2.0551064665621217,
#    'inverted_mean': 0.500159293199356,
#    'inverted_counts': 313335,
#    'inverted_nans': 3.5270716645124227,
#    'random_inverted_mean': 0.5009403105281697,
#    'random_inverted_counts': 312261,
#    'random_inverted_nans': 3.526271292284339,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5008375774892961,
#    'direct_counts': 312418,
#    'direct_nans': 3.8306307575107708,
#    'random_direct_mean': 0.49946575132570603,
#    'random_direct_counts': 313601,
#    'random_direct_nans': 3.828265853744089,
#    'inverted_mean': 0.5014500631734201,
#    'inverted_counts': 312346,
#    'inverted_nans': 1.754746338995857,
#    'random_inverted_mean': 0.5007831654300616,
#    'random_inverted_counts': 312948,
#    'random_inverted_nans': 1.7522591612664085,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5006866370455825,
#    'direct_counts': 312768,
#    'direct_nans': 1.9823095713116432,
#    'random_direct_mean': 0.500107044827205,
#    'random_direct_counts': 312522,
#    'random_direct_nans': 1.9816396925656434,
#    'inverted_mean': 0.5014065052953524,
#    'inverted_counts': 314408,
#    'inverted_nans': 3.5960121879850386,
#    'random_inverted_mean': 0.5005128288993954,
#    'random_inverted_counts': 313297,
#    'random_inverted_nans': 3.5951573107945496,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49928867288324397,
#    'direct_counts': 312902,
#    'direct_nans': 1.7948143508191063,
#    'random_direct_mean': 0.49949162074488235,
#    'random_direct_counts': 312858,
#    'random_direct_nans': 1.7966042102167756,
#    'inverted_mean': 0.5003458108558748,
#    'inverted_counts': 312453,
#    'inverted_nans': 3.7840955279674064,
#    'random_inverted_mean': 0.4996919981054918,
#    'random_inverted_counts': 312286,
#    'random_inverted_nans': 3.784847863817142,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49978537318050603,
#    'direct_counts': 314517,
#    'direct_nans': 2.785057723429894,
#    'random_direct_mean': 0.5001560465106375,
#    'random_direct_counts': 312915,
#    'random_direct_nans': 2.782381796973619,
#    'inverted_mean': 0.5011268028837118,
#    'inverted_counts': 312211,
#    'inverted_nans': 2.8024797332573166,
#    'random_inverted_mean': 0.5000247648235904,
#    'random_inverted_counts': 312557,
#    'random_inverted_nans': 2.7966834849323483,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5009741052066409,
#    'direct_counts': 313190,
#    'direct_nans': 2.165385229413455,
#    'random_direct_mean': 0.4999186805369688,
#    'random_direct_counts': 311823,
#    'random_direct_nans': 2.1634260461864585,
#    'inverted_mean': 0.5012189548593655,
#    'inverted_counts': 312256,
#    'inverted_nans': 3.416866289198606,
#    'random_inverted_mean': 0.4987358044574707,
#    'random_inverted_counts': 313588,
#    'random_inverted_nans': 3.4127581412554053,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49953161196460255,
#    'direct_counts': 313011,
#    'direct_nans': 3.1206251537485903,
#    'random_direct_mean': 0.5003811150710902,
#    'random_direct_counts': 313641,
#    'random_direct_nans': 3.1205263342483924,
#    'inverted_mean': 0.5009389446435755,
#    'inverted_counts': 312334,
#    'inverted_nans': 2.456581736218279,
#    'random_inverted_mean': 0.49925290720481036,
#    'random_inverted_counts': 311950,
#    'random_inverted_nans': 2.4599455040871936,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.4994556691617025,
#    'direct_counts': 311895,
#    'direct_nans': 3.7564853556485356,
#    'random_direct_mean': 0.5000026559656272,
#    'random_direct_counts': 313310,
#    'random_direct_nans': 3.754824295426255,
#    'inverted_mean': 0.5010715740430932,
#    'inverted_counts': 311649,
#    'inverted_nans': 1.8264297334501314,
#    'random_inverted_mean': 0.49920713842655945,
#    'random_inverted_counts': 312608,
#    'random_inverted_nans': 1.8199214351520114,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.4997991815084559,
#    'direct_counts': 313554,
#    'direct_nans': 3.555799001128992,
#    'random_direct_mean': 0.5004057197112416,
#    'random_direct_counts': 314078,
#    'random_direct_nans': 3.553906991256949,
#    'inverted_mean': 0.5010420465972231,
#    'inverted_counts': 311283,
#    'inverted_nans': 2.024164506253152,
#    'random_inverted_mean': 0.5002398444692525,
#    'random_inverted_counts': 312201,
#    'random_inverted_nans': 2.0217808399076236,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5002254282078945,
#    'direct_counts': 312022,
#    'direct_nans': 4.456374871002685,
#    'random_direct_mean': 0.4999120614459249,
#    'random_direct_counts': 313468,
#    'random_direct_nans': 4.454464251534447,
#    'inverted_mean': 0.5002585549341775,
#    'inverted_counts': 312744,
#    'inverted_nans': 1.120568260302356,
#    'random_inverted_mean': 0.49981369141349646,
#    'random_inverted_counts': 313702,
#    'random_inverted_nans': 1.1250007969346705,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49972179573644165,
#    'direct_counts': 311140,
#    'direct_nans': 2.9968277945619337,
#    'random_direct_mean': 0.5001082553938591,
#    'random_direct_counts': 312658,
#    'random_direct_nans': 2.999168420446622,
#    'inverted_mean': 0.5003017481559465,
#    'inverted_counts': 311007,
#    'inverted_nans': 2.580359927590054,
#    'random_inverted_mean': 0.49963544560305695,
#    'random_inverted_counts': 314097,
#    'random_inverted_nans': 2.577503128014594,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49947420618429256,
#    'direct_counts': 312453,
#    'direct_nans': 3.16630341203317,
#    'random_direct_mean': 0.4995446497656,
#    'random_direct_counts': 313260,
#    'random_direct_nans': 3.1695045648981677,
#    'inverted_mean': 0.4999269815830896,
#    'inverted_counts': 312112,
#    'inverted_nans': 2.4197980212231505,
#    'random_inverted_mean': 0.49973549702242986,
#    'random_inverted_counts': 312458,
#    'random_inverted_nans': 2.4138444206901406,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49959763731549106,
#    'direct_counts': 312362,
#    'direct_nans': 3.559168528822328,
#    'random_direct_mean': 0.4999640389494333,
#    'random_direct_counts': 312083,
#    'random_direct_nans': 3.559556271889209,
#    'inverted_mean': 0.5007465672675613,
#    'inverted_counts': 311779,
#    'inverted_nans': 2.019401563286815,
#    'random_inverted_mean': 0.5002181347613135,
#    'random_inverted_counts': 312153,
#    'random_inverted_nans': 2.020252888807732,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5005149001198173,
#    'direct_counts': 312807,
#    'direct_nans': 3.9151873199768548,
#    'random_direct_mean': 0.49967969827039144,
#    'random_direct_counts': 312423,
#    'random_direct_nans': 3.908054144541215,
#    'inverted_mean': 0.5002760018360632,
#    'inverted_counts': 313150,
#    'inverted_nans': 1.6659013252434935,
#    'random_inverted_mean': 0.4998243974876563,
#    'random_inverted_counts': 313364,
#    'random_inverted_nans': 1.6679356914004162,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5001350455772335,
#    'direct_counts': 312809,
#    'direct_nans': 1.2491104795578132,
#    'random_direct_mean': 0.4997752981729445,
#    'random_direct_counts': 312378,
#    'random_direct_nans': 1.2467363258616164,
#    'inverted_mean': 0.5003711063054171,
#    'inverted_counts': 311510,
#    'inverted_nans': 4.336313440981028,
#    'random_inverted_mean': 0.49883685830537083,
#    'random_inverted_counts': 312431,
#    'random_inverted_nans': 4.328738185391335,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49945129377275665,
#    'direct_counts': 312747,
#    'direct_nans': 1.849434207202627,
#    'random_direct_mean': 0.5001506789139789,
#    'random_direct_counts': 312584,
#    'random_direct_nans': 1.8514543290763443,
#    'inverted_mean': 0.5014203975369218,
#    'inverted_counts': 313747,
#    'inverted_nans': 3.726438818538504,
#    'random_inverted_mean': 0.5001983190041219,
#    'random_inverted_counts': 312975,
#    'random_inverted_nans': 3.7220065500439334,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5000494127592165,
#    'direct_counts': 311745,
#    'direct_nans': 3.3980881810454058,
#    'random_direct_mean': 0.5003009212099806,
#    'random_direct_counts': 312961,
#    'random_direct_nans': 3.3975447419966067,
#    'inverted_mean': 0.5009651959924009,
#    'inverted_counts': 311866,
#    'inverted_nans': 2.183331943847678,
#    'random_inverted_mean': 0.4991939558663326,
#    'random_inverted_counts': 313179,
#    'random_inverted_nans': 2.1812222403162407,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.4990950191951979,
#    'direct_counts': 312245,
#    'direct_nans': 3.1090169578375955,
#    'random_direct_mean': 0.5002158246945315,
#    'random_direct_counts': 312677,
#    'random_direct_nans': 3.1091829587721516,
#    'inverted_mean': 0.5003632389194627,
#    'inverted_counts': 311675,
#    'inverted_nans': 2.4693093767546324,
#    'random_inverted_mean': 0.49962885103456506,
#    'random_inverted_counts': 313411,
#    'random_inverted_nans': 2.469543187699219,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5002932699388463,
#    'direct_counts': 311128,
#    'direct_nans': 2.875353552235736,
#    'random_direct_mean': 0.4991479634466905,
#    'random_direct_counts': 313077,
#    'random_direct_nans': 2.8756535932055054,
#    'inverted_mean': 0.5000397279451892,
#    'inverted_counts': 312248,
#    'inverted_nans': 2.707469703568958,
#    'random_inverted_mean': 0.4992926295593833,
#    'random_inverted_counts': 312546,
#    'random_inverted_nans': 2.7031061027816707,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5013918472724095,
#    'direct_counts': 313682,
#    'direct_nans': 1.674530256756843,
#    'random_direct_mean': 0.4999068307986866,
#    'random_direct_counts': 313224,
#    'random_direct_nans': 1.6742395218757182,
#    'inverted_mean': 0.5002518402144258,
#    'inverted_counts': 311443,
#    'inverted_nans': 3.903304938624403,
#    'random_inverted_mean': 0.4996676909566929,
#    'random_inverted_counts': 311698,
#    'random_inverted_nans': 3.903592579997305,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.4998859455340352,
#    'direct_counts': 312079,
#    'direct_nans': 2.215249984779495,
#    'random_direct_mean': 0.5007057604622891,
#    'random_direct_counts': 312520,
#    'random_direct_nans': 2.218408421861001,
#    'inverted_mean': 0.5001019036578167,
#    'inverted_counts': 311288,
#    'inverted_nans': 3.3618417671095577,
#    'random_inverted_mean': 0.4997363853774311,
#    'random_inverted_counts': 312378,
#    'random_inverted_nans': 3.3627976361971714,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.4997605334616352,
#    'direct_counts': 313312,
#    'direct_nans': 2.247612603411296,
#    'random_direct_mean': 0.4997129862148376,
#    'random_direct_counts': 312998,
#    'random_direct_nans': 2.2410941922951584,
#    'inverted_mean': 0.5006706324454442,
#    'inverted_counts': 312163,
#    'inverted_nans': 3.3355394457382843,
#    'random_inverted_mean': 0.4998336852148294,
#    'random_inverted_counts': 312753,
#    'random_inverted_nans': 3.337010356415446,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49959028195577115,
#    'direct_counts': 311131,
#    'direct_nans': 2.400937225798779,
#    'random_direct_mean': 0.4999514405464942,
#    'random_direct_counts': 312576,
#    'random_direct_nans': 2.3979960073710074,
#    'inverted_mean': 0.5004143424287466,
#    'inverted_counts': 312455,
#    'inverted_nans': 3.1829415435822757,
#    'random_inverted_mean': 0.4995798849016799,
#    'random_inverted_counts': 314098,
#    'random_inverted_nans': 3.183732465663583,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.4997520790354047,
#    'direct_counts': 311595,
#    'direct_nans': 3.1041833148798923,
#    'random_direct_mean': 0.49944328215096284,
#    'random_direct_counts': 312332,
#    'random_direct_nans': 3.0989459933660335,
#    'inverted_mean': 0.49991856491143466,
#    'inverted_counts': 311342,
#    'inverted_nans': 2.4799770027815073,
#    'random_inverted_mean': 0.5004076274910327,
#    'random_inverted_counts': 312034,
#    'random_inverted_nans': 2.4769031579891934,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49977934808097246,
#    'direct_counts': 313156,
#    'direct_nans': 3.8915939659466847,
#    'random_direct_mean': 0.5012009208218844,
#    'random_direct_counts': 311949,
#    'random_direct_nans': 3.890770606733793,
#    'inverted_mean': 0.500372652781708,
#    'inverted_counts': 311789,
#    'inverted_nans': 1.6897966252818413,
#    'random_inverted_mean': 0.500199508875422,
#    'random_inverted_counts': 312441,
#    'random_inverted_nans': 1.6856238457820836,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.4992412170793279,
#    'direct_counts': 312060,
#    'direct_nans': 2.6240979298852785,
#    'random_direct_mean': 0.4992067302393859,
#    'random_direct_counts': 313073,
#    'random_direct_nans': 2.6238545003880884,
#    'inverted_mean': 0.49925998907873287,
#    'inverted_counts': 313440,
#    'inverted_nans': 2.9561989535477284,
#    'random_inverted_mean': 0.4991206305862303,
#    'random_inverted_counts': 312661,
#    'random_inverted_nans': 2.9540876540406384,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49991512117237646,
#    'direct_counts': 311828,
#    'direct_nans': 2.949270110445502,
#    'random_direct_mean': 0.5004041182533643,
#    'random_direct_counts': 311961,
#    'random_direct_nans': 2.94823070832572,
#    'inverted_mean': 0.4994115043561434,
#    'inverted_counts': 313263,
#    'inverted_nans': 2.635469238307748,
#    'random_inverted_mean': 0.5003694105440306,
#    'random_inverted_counts': 312573,
#    'random_inverted_nans': 2.6260777482380115,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5004970414041651,
#    'direct_counts': 312333,
#    'direct_nans': 2.8425878789625174,
#    'random_direct_mean': 0.5004101593132863,
#    'random_direct_counts': 313511,
#    'random_direct_nans': 2.8415749367645793,
#    'inverted_mean': 0.5008259453140397,
#    'inverted_counts': 314119,
#    'inverted_nans': 2.7427694599817265,
#    'random_inverted_mean': 0.49966103943403817,
#    'random_inverted_counts': 312714,
#    'random_inverted_nans': 2.735726574441822,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.49981333037727865,
#    'direct_counts': 311416,
#    'direct_nans': 2.7199180517378685,
#    'random_direct_mean': 0.50018386134479,
#    'random_direct_counts': 313142,
#    'random_direct_nans': 2.7253322773693722,
#    'inverted_mean': 0.49998930669184405,
#    'inverted_counts': 312068,
#    'inverted_nans': 2.8539901559916427,
#    'random_inverted_mean': 0.4991665248808936,
#    'random_inverted_counts': 312764,
#    'random_inverted_nans': 2.855159161540331,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5005096075978749,
#    'direct_counts': 312151,
#    'direct_nans': 1.7654660725097788,
#    'random_direct_mean': 0.4994282306508455,
#    'random_direct_counts': 312311,
#    'random_direct_nans': 1.7615613923300812,
#    'inverted_mean': 0.499091052555244,
#    'inverted_counts': 312378,
#    'inverted_nans': 3.8125156060926186,
#    'random_inverted_mean': 0.49991943862453825,
#    'random_inverted_counts': 312964,
#    'random_inverted_nans': 3.8161801357344616,
#    'window': 3,
#    'thr': 0.01},
#   {'direct_mean': 0.5009618478545212,
#    'direct_counts': 312088,
#    'direct_nans': 3.9926687344595115,
#    'random_direct_mean': 0.4992496670182782,
#    'random_direct_counts': 313177,
#    'random_direct_nans': 3.99110407213812,
#    'inverted_mean': 0.50031011097681,
#    'inverted_counts': 313349,
#    'inverted_nans': 1.5905651525934341,
#    'random_inverted_mean': 0.4997235480339033,
#    'random_inverted_counts': 311672,
#    'random_inverted_nans': 1.5858177827972997,
#    'window': 3,
#    'thr': 0.01}],
#  [{'direct_mean': 0.5000692771566253,
#    'direct_counts': 235027,
#    'direct_nans': 3.1392861245729216,
#    'random_direct_mean': 0.49921624643643603,
#    'random_direct_counts': 234775,
#    'random_direct_nans': 3.145100628261101,
#    'inverted_mean': 0.500387981489199,
#    'inverted_counts': 234565,
#    'inverted_nans': 2.4406497132990856,
#    'random_inverted_mean': 0.4991743431445536,
#    'random_inverted_counts': 234984,
#    'random_inverted_nans': 2.4366382391992647,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5008134931213998,
#    'direct_counts': 234280,
#    'direct_nans': 4.1022622502987875,
#    'random_direct_mean': 0.5011494360638377,
#    'random_direct_counts': 234327,
#    'random_direct_nans': 4.101810717501611,
#    'inverted_mean': 0.5002604705192485,
#    'inverted_counts': 234812,
#    'inverted_nans': 1.4783316014513739,
#    'random_inverted_mean': 0.49936047048709037,
#    'random_inverted_counts': 235014,
#    'random_inverted_nans': 1.4707549337486276,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.4989158398112517,
#    'direct_counts': 234949,
#    'direct_nans': 2.142354298166836,
#    'random_direct_mean': 0.5008915197014512,
#    'random_direct_counts': 234544,
#    'random_direct_nans': 2.1421268503990722,
#    'inverted_mean': 0.49988576704746357,
#    'inverted_counts': 233396,
#    'inverted_nans': 3.441160088433392,
#    'random_inverted_mean': 0.49912020060807766,
#    'random_inverted_counts': 234261,
#    'random_inverted_nans': 3.4387584787907506,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5010871113060908,
#    'direct_counts': 235461,
#    'direct_nans': 2.9676421997698132,
#    'random_direct_mean': 0.5000558733813969,
#    'random_direct_counts': 234230,
#    'random_direct_nans': 2.9625965930922598,
#    'inverted_mean': 0.501512429019427,
#    'inverted_counts': 233640,
#    'inverted_nans': 2.6128531073446326,
#    'random_inverted_mean': 0.49991855763776033,
#    'random_inverted_counts': 234482,
#    'random_inverted_nans': 2.610260062606085,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5016749127243129,
#    'direct_counts': 235552,
#    'direct_nans': 2.817118937644342,
#    'random_direct_mean': 0.49926567252351034,
#    'random_direct_counts': 235269,
#    'random_direct_nans': 2.8177787978866746,
#    'inverted_mean': 0.49933644027900154,
#    'inverted_counts': 234017,
#    'inverted_nans': 2.761957464628638,
#    'random_inverted_mean': 0.5008539742892791,
#    'random_inverted_counts': 234541,
#    'random_inverted_nans': 2.760387309681463,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5001832237561821,
#    'direct_counts': 235552,
#    'direct_nans': 2.4213422089390026,
#    'random_direct_mean': 0.500441392195676,
#    'random_direct_counts': 235108,
#    'random_direct_nans': 2.421261718018953,
#    'inverted_mean': 0.501255242353232,
#    'inverted_counts': 234845,
#    'inverted_nans': 3.1596883050522684,
#    'random_inverted_mean': 0.4994227622115498,
#    'random_inverted_counts': 235280,
#    'random_inverted_nans': 3.159448316899014,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5008220023922987,
#    'direct_counts': 234798,
#    'direct_nans': 3.1417558922989124,
#    'random_direct_mean': 0.49928345294552007,
#    'random_direct_counts': 234667,
#    'random_direct_nans': 3.1449330327655787,
#    'inverted_mean': 0.5004904789778799,
#    'inverted_counts': 235654,
#    'inverted_nans': 2.4342892545851122,
#    'random_inverted_mean': 0.5004564410279195,
#    'random_inverted_counts': 234292,
#    'random_inverted_nans': 2.4368352312498933,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.4997750542827518,
#    'direct_counts': 235030,
#    'direct_nans': 3.549623452325235,
#    'random_direct_mean': 0.5006318114326722,
#    'random_direct_counts': 234008,
#    'random_direct_nans': 3.5561989333697994,
#    'inverted_mean': 0.5003663670594303,
#    'inverted_counts': 235010,
#    'inverted_nans': 2.020952299902132,
#    'random_inverted_mean': 0.5000306746269875,
#    'random_inverted_counts': 235695,
#    'random_inverted_nans': 2.023186745582214,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.4997363327289237,
#    'direct_counts': 234595,
#    'direct_nans': 3.1889085445128837,
#    'random_direct_mean': 0.4988763169115206,
#    'random_direct_counts': 234676,
#    'random_direct_nans': 3.1897935877550325,
#    'inverted_mean': 0.500603521077977,
#    'inverted_counts': 235570,
#    'inverted_nans': 2.387540858343592,
#    'random_inverted_mean': 0.5010619138988038,
#    'random_inverted_counts': 235557,
#    'random_inverted_nans': 2.3880249790921093,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5004345234445525,
#    'direct_counts': 234034,
#    'direct_nans': 3.3383653657160925,
#    'random_direct_mean': 0.5005432714740295,
#    'random_direct_counts': 235196,
#    'random_direct_nans': 3.334287147740608,
#    'inverted_mean': 0.5011813202795049,
#    'inverted_counts': 236238,
#    'inverted_nans': 2.2486560163902505,
#    'random_inverted_mean': 0.5004569395002672,
#    'random_inverted_counts': 234539,
#    'random_inverted_nans': 2.247391691786867,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.4997310996762449,
#    'direct_counts': 235264,
#    'direct_nans': 2.458297912132753,
#    'random_direct_mean': 0.5002603439777388,
#    'random_direct_counts': 235285,
#    'random_direct_nans': 2.4579169942835284,
#    'inverted_mean': 0.49989703986784506,
#    'inverted_counts': 235519,
#    'inverted_nans': 3.1179225455271125,
#    'random_inverted_mean': 0.49938424705968776,
#    'random_inverted_counts': 234080,
#    'random_inverted_nans': 3.1219198564593302,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5003664153983568,
#    'direct_counts': 234443,
#    'direct_nans': 2.2483844687194754,
#    'random_direct_mean': 0.4989114310199486,
#    'random_direct_counts': 235148,
#    'random_direct_nans': 2.2463342235528265,
#    'inverted_mean': 0.5000262897916127,
#    'inverted_counts': 233090,
#    'inverted_nans': 3.3343472478441805,
#    'random_inverted_mean': 0.4998642746473747,
#    'random_inverted_counts': 234662,
#    'random_inverted_nans': 3.332657183523536,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5011074571490011,
#    'direct_counts': 234640,
#    'direct_nans': 3.7448900443232187,
#    'random_direct_mean': 0.5003687897519858,
#    'random_direct_counts': 234563,
#    'random_direct_nans': 3.7462344871100726,
#    'inverted_mean': 0.5009741837669976,
#    'inverted_counts': 235388,
#    'inverted_nans': 1.8341249341512735,
#    'random_inverted_mean': 0.5000361167455577,
#    'random_inverted_counts': 234826,
#    'random_inverted_nans': 1.832020304395595,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.499989088846928,
#    'direct_counts': 235740,
#    'direct_nans': 2.5279078645965893,
#    'random_direct_mean': 0.499212880961315,
#    'random_direct_counts': 234058,
#    'random_direct_nans': 2.5312614821967205,
#    'inverted_mean': 0.4993523918185867,
#    'inverted_counts': 235762,
#    'inverted_nans': 3.0520991508385573,
#    'random_inverted_mean': 0.5006333657216108,
#    'random_inverted_counts': 235515,
#    'random_inverted_nans': 3.049308961212662,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5006572857745256,
#    'direct_counts': 236029,
#    'direct_nans': 2.6632235869321144,
#    'random_direct_mean': 0.4999768243061032,
#    'random_direct_counts': 234279,
#    'random_direct_nans': 2.663362913449349,
#    'inverted_mean': 0.5009315847660868,
#    'inverted_counts': 234011,
#    'inverted_nans': 2.9153202199896584,
#    'random_inverted_mean': 0.5000383253606027,
#    'random_inverted_counts': 234531,
#    'random_inverted_nans': 2.9159258264365904,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5022516070959951,
#    'direct_counts': 235249,
#    'direct_nans': 3.180102784708968,
#    'random_direct_mean': 0.49998649525345773,
#    'random_direct_counts': 234364,
#    'random_direct_nans': 3.176255738936014,
#    'inverted_mean': 0.5007974053446975,
#    'inverted_counts': 234343,
#    'inverted_nans': 2.3985738852878047,
#    'random_inverted_mean': 0.4999532460133431,
#    'random_inverted_counts': 234131,
#    'random_inverted_nans': 2.4007628208139886,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.49910860309406635,
#    'direct_counts': 235113,
#    'direct_nans': 3.164474103941509,
#    'random_direct_mean': 0.4995928243758163,
#    'random_direct_counts': 234931,
#    'random_direct_nans': 3.1615240219468697,
#    'inverted_mean': 0.5020727225115087,
#    'inverted_counts': 234905,
#    'inverted_nans': 2.4173346672058917,
#    'random_inverted_mean': 0.49926959079999317,
#    'random_inverted_counts': 234189,
#    'random_inverted_nans': 2.4179231304630022,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5007513374603668,
#    'direct_counts': 235518,
#    'direct_nans': 2.9542795030528453,
#    'random_direct_mean': 0.500161976743813,
#    'random_direct_counts': 233635,
#    'random_direct_nans': 2.9515269544374774,
#    'inverted_mean': 0.5007668148603212,
#    'inverted_counts': 233830,
#    'inverted_nans': 2.6276269084377537,
#    'random_inverted_mean': 0.5004396344965949,
#    'random_inverted_counts': 235171,
#    'random_inverted_nans': 2.629690735677443,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5004735041932301,
#    'direct_counts': 234639,
#    'direct_nans': 2.981597262177217,
#    'random_direct_mean': 0.5002591422349738,
#    'random_direct_counts': 234808,
#    'random_direct_nans': 2.983731389049777,
#    'inverted_mean': 0.5006851173398218,
#    'inverted_counts': 234457,
#    'inverted_nans': 2.5893873929974367,
#    'random_inverted_mean': 0.49923419700613586,
#    'random_inverted_counts': 235405,
#    'random_inverted_nans': 2.5961130817102442,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5004764721549859,
#    'direct_counts': 233899,
#    'direct_nans': 2.41269949850149,
#    'random_direct_mean': 0.4995508841477242,
#    'random_direct_counts': 234607,
#    'random_direct_nans': 2.407630633357061,
#    'inverted_mean': 0.49964212785974205,
#    'inverted_counts': 234788,
#    'inverted_nans': 3.1671209772220044,
#    'random_inverted_mean': 0.5000020503806277,
#    'random_inverted_counts': 234419,
#    'random_inverted_nans': 3.1710142949163678,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.50057162628128,
#    'direct_counts': 234693,
#    'direct_nans': 3.8804736400318713,
#    'random_direct_mean': 0.49990330317353776,
#    'random_direct_counts': 234672,
#    'random_direct_nans': 3.8841915524647166,
#    'inverted_mean': 0.5010156198650406,
#    'inverted_counts': 234896,
#    'inverted_nans': 1.6994840269736393,
#    'random_inverted_mean': 0.49953424183853457,
#    'random_inverted_counts': 234804,
#    'random_inverted_nans': 1.6959464063644571,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5006649321137493,
#    'direct_counts': 235360,
#    'direct_nans': 3.2563264785859958,
#    'random_direct_mean': 0.5007139704552479,
#    'random_direct_counts': 234326,
#    'random_direct_nans': 3.247364782397173,
#    'inverted_mean': 0.5002769023784814,
#    'inverted_counts': 234467,
#    'inverted_nans': 2.325947787961632,
#    'random_inverted_mean': 0.5006239913293848,
#    'random_inverted_counts': 234009,
#    'random_inverted_nans': 2.3305770290886247,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5002985467788312,
#    'direct_counts': 235730,
#    'direct_nans': 3.3506299580028,
#    'random_direct_mean': 0.49966646304267376,
#    'random_direct_counts': 234814,
#    'random_direct_nans': 3.350221877741532,
#    'inverted_mean': 0.4992254433806103,
#    'inverted_counts': 234605,
#    'inverted_nans': 2.2363888237676095,
#    'random_inverted_mean': 0.49965200383492114,
#    'random_inverted_counts': 234925,
#    'random_inverted_nans': 2.2332233691603705,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.500950102774148,
#    'direct_counts': 234338,
#    'direct_nans': 4.011214570406848,
#    'random_direct_mean': 0.5004878325265139,
#    'random_direct_counts': 234335,
#    'random_direct_nans': 4.008201933129921,
#    'inverted_mean': 0.49963423987599825,
#    'inverted_counts': 235785,
#    'inverted_nans': 1.572059291303518,
#    'random_inverted_mean': 0.4997694492736097,
#    'random_inverted_counts': 234403,
#    'random_inverted_nans': 1.567642052362811,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5013930220606093,
#    'direct_counts': 235465,
#    'direct_nans': 3.4947359480177522,
#    'random_direct_mean': 0.5007277359657014,
#    'random_direct_counts': 233914,
#    'random_direct_nans': 3.4960156296758638,
#    'inverted_mean': 0.5012880075410565,
#    'inverted_counts': 234034,
#    'inverted_nans': 2.0856713127152466,
#    'random_inverted_mean': 0.500185704696471,
#    'random_inverted_counts': 234738,
#    'random_inverted_nans': 2.0812224693062054,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5000669001109926,
#    'direct_counts': 234524,
#    'direct_nans': 3.2110828742474116,
#    'random_direct_mean': 0.5000534090692238,
#    'random_direct_counts': 233634,
#    'random_direct_nans': 3.215109958310862,
#    'inverted_mean': 0.4997460121073817,
#    'inverted_counts': 234948,
#    'inverted_nans': 2.362999472223641,
#    'random_inverted_mean': 0.4991477953725944,
#    'random_inverted_counts': 234494,
#    'random_inverted_nans': 2.3637875595964077,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.4989371409636748,
#    'direct_counts': 234219,
#    'direct_nans': 3.6009418535643993,
#    'random_direct_mean': 0.5007495290248781,
#    'random_direct_counts': 235439,
#    'random_direct_nans': 3.5968424942341755,
#    'inverted_mean': 0.4999993203135955,
#    'inverted_counts': 234634,
#    'inverted_nans': 1.9853729638500814,
#    'random_inverted_mean': 0.49919629388800707,
#    'random_inverted_counts': 234256,
#    'random_inverted_nans': 1.9829886961273138,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5002526557384762,
#    'direct_counts': 235524,
#    'direct_nans': 2.4409359555714065,
#    'random_direct_mean': 0.5005887221982444,
#    'random_direct_counts': 233986,
#    'random_direct_nans': 2.4398724710025386,
#    'inverted_mean': 0.5011009041360626,
#    'inverted_counts': 234298,
#    'inverted_nans': 3.1435266199455394,
#    'random_inverted_mean': 0.4997164676975788,
#    'random_inverted_counts': 234621,
#    'random_inverted_nans': 3.1372340924299187,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5007367341852537,
#    'direct_counts': 234588,
#    'direct_nans': 4.485762272580013,
#    'random_direct_mean': 0.5009714890765254,
#    'random_direct_counts': 234602,
#    'random_direct_nans': 4.483435776336092,
#    'inverted_mean': 0.5000546273259582,
#    'inverted_counts': 234386,
#    'inverted_nans': 1.0925183244733048,
#    'random_inverted_mean': 0.4991002282601812,
#    'random_inverted_counts': 235233,
#    'random_inverted_nans': 1.0945488090531517,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5004231817515037,
#    'direct_counts': 234345,
#    'direct_nans': 2.781245599436728,
#    'random_direct_mean': 0.49985509425642544,
#    'random_direct_counts': 234074,
#    'random_direct_nans': 2.7840768304040604,
#    'inverted_mean': 0.5004160318363835,
#    'inverted_counts': 234944,
#    'inverted_nans': 2.7910353105420866,
#    'random_inverted_mean': 0.49987480068405304,
#    'random_inverted_counts': 234355,
#    'random_inverted_nans': 2.79134646156472,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5006838604314786,
#    'direct_counts': 234085,
#    'direct_nans': 3.428596450007476,
#    'random_direct_mean': 0.49955053621460604,
#    'random_direct_counts': 234342,
#    'random_direct_nans': 3.4236287135895402,
#    'inverted_mean': 0.5013704490293979,
#    'inverted_counts': 234750,
#    'inverted_nans': 2.1534100106496274,
#    'random_inverted_mean': 0.4997954088699313,
#    'random_inverted_counts': 234556,
#    'random_inverted_nans': 2.1567003189003904,
#    'window': 2,
#    'thr': 0.0075},
#   {'direct_mean': 0.5004628351237899,
#    'direct_counts': 235485,
#    'direct_nans': 2.4991910312758776,
#    'random_direct_mean': 0.4997710488638388,
#    'random_direct_counts': 234643,
#    'random_direct_nans': 2.4975004581427958,
#    'inverted_mean': 0.5005844725738998,
# ...
#    'thr': 0.001}],
#  [{'direct_mean': 0.5011035895353849,
#    'direct_counts': 31240,
#    'direct_nans': 3.042349551856594,
#    'random_direct_mean': 0.5011523521908976,
#    'random_direct_counts': 31216,
#    'random_direct_nans': 3.026172475653511,
#    'inverted_mean': 0.5007125558946746,
#    'inverted_counts': 31629,
#    'inverted_nans': 2.5596446299282305,
#    'random_inverted_mean': 0.5006999478275682,
#    'random_inverted_counts': 31412,
#    'random_inverted_nans': 2.550935948045333,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5009099714326264,
#    'direct_counts': 31263,
#    'direct_nans': 1.9444391133288552,
#    'random_direct_mean': 0.49582988984874954,
#    'random_direct_counts': 31399,
#    'random_direct_nans': 1.9307939743303928,
#    'inverted_mean': 0.4992702856839548,
#    'inverted_counts': 31094,
#    'inverted_nans': 3.643178748311571,
#    'random_inverted_mean': 0.5020870657088745,
#    'random_inverted_counts': 31206,
#    'random_inverted_nans': 3.6452284817022367,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.4989592893378656,
#    'direct_counts': 30976,
#    'direct_nans': 2.7962293388429753,
#    'random_direct_mean': 0.5010968183143915,
#    'random_direct_counts': 31216,
#    'random_direct_nans': 2.7946886212198874,
#    'inverted_mean': 0.502099053279989,
#    'inverted_counts': 30953,
#    'inverted_nans': 2.778890576034633,
#    'random_inverted_mean': 0.4988443242606047,
#    'random_inverted_counts': 31171,
#    'random_inverted_nans': 2.7737319944820507,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5009303458042952,
#    'direct_counts': 31296,
#    'direct_nans': 3.147590746421268,
#    'random_direct_mean': 0.5003745057867935,
#    'random_direct_counts': 31145,
#    'random_direct_nans': 3.150200674265532,
#    'inverted_mean': 0.4996324152102883,
#    'inverted_counts': 31107,
#    'inverted_nans': 2.459767897900794,
#    'random_inverted_mean': 0.499773835336434,
#    'random_inverted_counts': 31092,
#    'random_inverted_nans': 2.4245786697542777,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.502812695344897,
#    'direct_counts': 31238,
#    'direct_nans': 2.7723605864652026,
#    'random_direct_mean': 0.49913632186400547,
#    'random_direct_counts': 31188,
#    'random_direct_nans': 2.778248044119533,
#    'inverted_mean': 0.49815722535594126,
#    'inverted_counts': 30739,
#    'inverted_nans': 2.817951136992095,
#    'random_inverted_mean': 0.4973961117155845,
#    'random_inverted_counts': 31168,
#    'random_inverted_nans': 2.7859022073921973,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5028205419214369,
#    'direct_counts': 31254,
#    'direct_nans': 3.1426377423689766,
#    'random_direct_mean': 0.5048709629187583,
#    'random_direct_counts': 31189,
#    'random_direct_nans': 3.129629035878034,
#    'inverted_mean': 0.49774071585300267,
#    'inverted_counts': 31034,
#    'inverted_nans': 2.4271121995231035,
#    'random_inverted_mean': 0.49859047475153406,
#    'random_inverted_counts': 31052,
#    'random_inverted_nans': 2.4276375112714157,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.4999831355025614,
#    'direct_counts': 31147,
#    'direct_nans': 3.104921822326388,
#    'random_direct_mean': 0.4985955488440241,
#    'random_direct_counts': 31162,
#    'random_direct_nans': 3.0965599127142034,
#    'inverted_mean': 0.5012658043795759,
#    'inverted_counts': 31203,
#    'inverted_nans': 2.480242284395731,
#    'random_inverted_mean': 0.501565182874298,
#    'random_inverted_counts': 31180,
#    'random_inverted_nans': 2.4713598460551633,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.4991267012608199,
#    'direct_counts': 30989,
#    'direct_nans': 3.852399238439446,
#    'random_direct_mean': 0.5001201775993901,
#    'random_direct_counts': 31225,
#    'random_direct_nans': 3.8476220976781423,
#    'inverted_mean': 0.5005345063219689,
#    'inverted_counts': 31047,
#    'inverted_nans': 1.7488968338325763,
#    'random_inverted_mean': 0.4980789502909945,
#    'random_inverted_counts': 31231,
#    'random_inverted_nans': 1.7252409464954692,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5009945358398528,
#    'direct_counts': 31132,
#    'direct_nans': 2.7627521521264296,
#    'random_direct_mean': 0.5008631587213486,
#    'random_direct_counts': 30754,
#    'random_direct_nans': 2.763380373284776,
#    'inverted_mean': 0.4989800866117389,
#    'inverted_counts': 30785,
#    'inverted_nans': 2.8265713821666396,
#    'random_inverted_mean': 0.49850951087908385,
#    'random_inverted_counts': 31449,
#    'random_inverted_nans': 2.815129256892111,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49939724073196434,
#    'direct_counts': 31084,
#    'direct_nans': 2.3382769270364174,
#    'random_direct_mean': 0.49796601095702203,
#    'random_direct_counts': 31147,
#    'random_direct_nans': 2.3391016791344272,
#    'inverted_mean': 0.504550112429308,
#    'inverted_counts': 31123,
#    'inverted_nans': 3.2407865565658835,
#    'random_inverted_mean': 0.4988649945349903,
#    'random_inverted_counts': 31160,
#    'random_inverted_nans': 3.224775353016688,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5032318215738397,
#    'direct_counts': 31682,
#    'direct_nans': 3.218010226627107,
#    'random_direct_mean': 0.5021214598867125,
#    'random_direct_counts': 31431,
#    'random_direct_nans': 3.2301231268492887,
#    'inverted_mean': 0.4995143950492788,
#    'inverted_counts': 31045,
#    'inverted_nans': 2.3498469962956996,
#    'random_inverted_mean': 0.49848579054663306,
#    'random_inverted_counts': 31369,
#    'random_inverted_nans': 2.338072619465077,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5012285782355738,
#    'direct_counts': 31450,
#    'direct_nans': 2.9349761526232117,
#    'random_direct_mean': 0.4983643447792406,
#    'random_direct_counts': 31292,
#    'random_direct_nans': 2.9270420554774383,
#    'inverted_mean': 0.49741246877758644,
#    'inverted_counts': 31233,
#    'inverted_nans': 2.6311593506867736,
#    'random_inverted_mean': 0.49936919966632054,
#    'random_inverted_counts': 31085,
#    'random_inverted_nans': 2.6329419334083966,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5059760216037489,
#    'direct_counts': 31025,
#    'direct_nans': 3.1803706688154714,
#    'random_direct_mean': 0.4996658966213672,
#    'random_direct_counts': 31297,
#    'random_direct_nans': 3.1699843435473047,
#    'inverted_mean': 0.4973562066189374,
#    'inverted_counts': 31342,
#    'inverted_nans': 2.393912322123668,
#    'random_inverted_mean': 0.501136230260716,
#    'random_inverted_counts': 31354,
#    'random_inverted_nans': 2.401735025834024,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49993919007389404,
#    'direct_counts': 31263,
#    'direct_nans': 2.602021559031443,
#    'random_direct_mean': 0.4995380811398263,
#    'random_direct_counts': 31719,
#    'random_direct_nans': 2.5993568523597843,
#    'inverted_mean': 0.4984230971677147,
#    'inverted_counts': 31434,
#    'inverted_nans': 2.959088884647197,
#    'random_inverted_mean': 0.5025985596065913,
#    'random_inverted_counts': 31315,
#    'random_inverted_nans': 2.9777422960242697,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.4967178065301816,
#    'direct_counts': 30940,
#    'direct_nans': 2.438009049773756,
#    'random_direct_mean': 0.5010392355722396,
#    'random_direct_counts': 31074,
#    'random_direct_nans': 2.429844886400206,
#    'inverted_mean': 0.4975986048786921,
#    'inverted_counts': 31427,
#    'inverted_nans': 3.161517166767429,
#    'random_inverted_mean': 0.49964082124925496,
#    'random_inverted_counts': 31137,
#    'random_inverted_nans': 3.154157433278736,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.500065170185753,
#    'direct_counts': 31090,
#    'direct_nans': 3.8145384367963975,
#    'random_direct_mean': 0.49882239151490787,
#    'random_direct_counts': 31438,
#    'random_direct_nans': 3.8025955849608755,
#    'inverted_mean': 0.4965100221828523,
#    'inverted_counts': 31390,
#    'inverted_nans': 1.7629818413507485,
#    'random_inverted_mean': 0.4993692048076964,
#    'random_inverted_counts': 31132,
#    'random_inverted_nans': 1.776660670692535,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49845529283888607,
#    'direct_counts': 31077,
#    'direct_nans': 2.851755317437333,
#    'random_direct_mean': 0.49947844474173136,
#    'random_direct_counts': 31597,
#    'random_direct_nans': 2.846536063550337,
#    'inverted_mean': 0.4996634220004675,
#    'inverted_counts': 31207,
#    'inverted_nans': 2.737014131444868,
#    'random_inverted_mean': 0.49920834091682675,
#    'random_inverted_counts': 31131,
#    'random_inverted_nans': 2.7315216343837334,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49983344321043166,
#    'direct_counts': 31474,
#    'direct_nans': 2.9118319883078096,
#    'random_direct_mean': 0.4988437140928355,
#    'random_direct_counts': 31589,
#    'random_direct_nans': 2.911741428978442,
#    'inverted_mean': 0.4997281077634324,
#    'inverted_counts': 31404,
#    'inverted_nans': 2.6676538020634313,
#    'random_inverted_mean': 0.4995450838681974,
#    'random_inverted_counts': 31406,
#    'random_inverted_nans': 2.6546838183786536,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5007240235028213,
#    'direct_counts': 30991,
#    'direct_nans': 2.2984737504436774,
#    'random_direct_mean': 0.5005384195105185,
#    'random_direct_counts': 31671,
#    'random_direct_nans': 2.3026743708755646,
#    'inverted_mean': 0.5009403555323149,
#    'inverted_counts': 31345,
#    'inverted_nans': 3.272611261764237,
#    'random_inverted_mean': 0.5004172936036425,
#    'random_inverted_counts': 31072,
#    'random_inverted_nans': 3.2773236354273942,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49857660457219605,
#    'direct_counts': 31643,
#    'direct_nans': 3.0255032708655945,
#    'random_direct_mean': 0.4995643462881536,
#    'random_direct_counts': 31260,
#    'random_direct_nans': 3.0098528470889314,
#    'inverted_mean': 0.500878909331284,
#    'inverted_counts': 30808,
#    'inverted_nans': 2.5719293689950664,
#    'random_inverted_mean': 0.5021996639305094,
#    'random_inverted_counts': 31644,
#    'random_inverted_nans': 2.5781506762735433,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49832276157507427,
#    'direct_counts': 31465,
#    'direct_nans': 3.2992849197521057,
#    'random_direct_mean': 0.49791732877116257,
#    'random_direct_counts': 31029,
#    'random_direct_nans': 3.2870540462148314,
#    'inverted_mean': 0.5025857462338738,
#    'inverted_counts': 30857,
#    'inverted_nans': 2.264056778040639,
#    'random_inverted_mean': 0.5006153339540516,
#    'random_inverted_counts': 31501,
#    'random_inverted_nans': 2.272880226024571,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49634326741160006,
#    'direct_counts': 30983,
#    'direct_nans': 3.6445470096504535,
#    'random_direct_mean': 0.5007437854842226,
#    'random_direct_counts': 31161,
#    'random_direct_nans': 3.6463528128108855,
#    'inverted_mean': 0.5053929910571283,
#    'inverted_counts': 31078,
#    'inverted_nans': 1.9437544243516314,
#    'random_inverted_mean': 0.5004126552775531,
#    'random_inverted_counts': 30913,
#    'random_inverted_nans': 1.9360463235531977,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5011272404520714,
#    'direct_counts': 30823,
#    'direct_nans': 3.311033968140674,
#    'random_direct_mean': 0.5017660978330409,
#    'random_direct_counts': 31339,
#    'random_direct_nans': 3.3286639650276015,
#    'inverted_mean': 0.501872176407853,
#    'inverted_counts': 31274,
#    'inverted_nans': 2.246690541664002,
#    'random_inverted_mean': 0.500413138535705,
#    'random_inverted_counts': 31414,
#    'random_inverted_nans': 2.250907238810721,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.4977981039854818,
#    'direct_counts': 31203,
#    'direct_nans': 3.8104348940806974,
#    'random_direct_mean': 0.4990684861765375,
#    'random_direct_counts': 31110,
#    'random_direct_nans': 3.787399549983928,
#    'inverted_mean': 0.501567748277168,
#    'inverted_counts': 30786,
#    'inverted_nans': 1.7839602416682907,
#    'random_inverted_mean': 0.4987753621417042,
#    'random_inverted_counts': 31493,
#    'random_inverted_nans': 1.7729654208871812,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49793770199974274,
#    'direct_counts': 31347,
#    'direct_nans': 2.2967748109866974,
#    'random_direct_mean': 0.4998553773086913,
#    'random_direct_counts': 31107,
#    'random_direct_nans': 2.292763686630019,
#    'inverted_mean': 0.4994069456047189,
#    'inverted_counts': 31139,
#    'inverted_nans': 3.294164873631138,
#    'random_inverted_mean': 0.49792805062771467,
#    'random_inverted_counts': 31407,
#    'random_inverted_nans': 3.2820071958480592,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49700917463646943,
#    'direct_counts': 31016,
#    'direct_nans': 3.8303456280629353,
#    'random_direct_mean': 0.5007849280015612,
#    'random_direct_counts': 31273,
#    'random_direct_nans': 3.805870879033032,
#    'inverted_mean': 0.5010362129017374,
#    'inverted_counts': 31270,
#    'inverted_nans': 1.7596098496961945,
#    'random_inverted_mean': 0.4994460180426905,
#    'random_inverted_counts': 31263,
#    'random_inverted_nans': 1.747497041230848,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5032806586150816,
#    'direct_counts': 31041,
#    'direct_nans': 1.8687542282787282,
#    'random_direct_mean': 0.49777822012499057,
#    'random_direct_counts': 31339,
#    'random_direct_nans': 1.8678643224097768,
#    'inverted_mean': 0.5037221964065827,
#    'inverted_counts': 31347,
#    'inverted_nans': 3.710020097616997,
#    'random_inverted_mean': 0.49717899904310586,
#    'random_inverted_counts': 31227,
#    'random_inverted_nans': 3.708969801774106,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49878643495875735,
#    'direct_counts': 30900,
#    'direct_nans': 3.387443365695793,
#    'random_direct_mean': 0.4979072551889898,
#    'random_direct_counts': 31229,
#    'random_direct_nans': 3.386787921483237,
#    'inverted_mean': 0.5031723276359411,
#    'inverted_counts': 30959,
#    'inverted_nans': 2.1919635647146225,
#    'random_inverted_mean': 0.5016603707195277,
#    'random_inverted_counts': 31050,
#    'random_inverted_nans': 2.1880193236714978,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5029967202441871,
#    'direct_counts': 31284,
#    'direct_nans': 1.9494310190512723,
#    'random_direct_mean': 0.4984363390495406,
#    'random_direct_counts': 31010,
#    'random_direct_nans': 1.9491454369558208,
#    'inverted_mean': 0.49738861112794963,
#    'inverted_counts': 30828,
#    'inverted_nans': 3.6530426884650318,
#    'random_inverted_mean': 0.4992523134315578,
#    'random_inverted_counts': 31216,
#    'random_inverted_nans': 3.627883136852896,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.49979560996448674,
#    'direct_counts': 30970,
#    'direct_nans': 2.7378430739425252,
#    'random_direct_mean': 0.49930940608147373,
#    'random_direct_counts': 31193,
#    'random_direct_nans': 2.729875292533581,
#    'inverted_mean': 0.5000899681799524,
#    'inverted_counts': 31166,
#    'inverted_nans': 2.8524353462106142,
#    'random_inverted_mean': 0.5035923529068742,
#    'random_inverted_counts': 31306,
#    'random_inverted_nans': 2.8428096850444002,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5025047862753593,
#    'direct_counts': 31785,
#    'direct_nans': 2.8365581249016834,
#    'random_direct_mean': 0.5004513739311491,
#    'random_direct_counts': 31251,
#    'random_direct_nans': 2.828389491536271,
#    'inverted_mean': 0.49915405933806367,
#    'inverted_counts': 30922,
#    'inverted_nans': 2.7484638768514325,
#    'random_inverted_mean': 0.4962537425129558,
#    'random_inverted_counts': 31419,
#    'random_inverted_nans': 2.740443680575448,
#    'window': 3,
#    'thr': 0.001},
#   {'direct_mean': 0.5000956281529007,
#    'direct_counts': 31193,
#    'direct_nans': 3.6243708524348413,
#    'random_direct_mean': 0.5016589985989276,
#    'random_direct_counts': 31148,
#    'random_direct_nans': 3.5980159239758573,
#    'inverted_mean': 0.49784436980321156,
#    'inverted_counts': 31506,
#    'inverted_nans': 1.9862248460610676,
#    'random_inverted_mean': 0.4998330658682154,
#    'random_inverted_counts': 31261,
#    'random_inverted_nans': 1.9687470010556285,
#    'window': 3,
#    'thr': 0.001}]]

# %%
# add save

# %%
results = pd.read_pickle('scan_results.pickle')

# %%
results.random_direct_mean.mean()
# Out:
# 0.5000083814256147

# %%
results.direct_mean.mean()
# Out:
# 0.5003085105775387

# %%
results.inverted_mean.mean()
# Out:
# 0.5003928619899972

# %%
results.random_inverted_mean.mean()
# Out:
# 0.49984293204069524

# %%
results.direct_mean.std()
# Out:
# 0.0012493638645021626

# %%
results
# Out:
#      direct_mean  direct_counts  direct_nans  random_direct_mean  \
# 0       0.500396         313197     3.999071            0.500439
# 1       0.500430         313421     2.816825            0.500418
# 2       0.500626         311300     4.647196            0.500954
# 3       0.500351         312969     3.069579            0.499574
# 4       0.501174         314178     2.725926            0.499938
# ..           ...            ...          ...                 ...
# 315     0.498786          30900     3.387443            0.497907
# 316     0.502997          31284     1.949431            0.498436
# 317     0.499796          30970     2.737843            0.499309
# 318     0.502505          31785     2.836558            0.500451
# 319     0.500096          31193     3.624371            0.501659
#
#      random_direct_counts  random_direct_nans  inverted_mean  inverted_counts  \
# 0                  312361            3.998671       0.499634           313971
# 1                  314199            2.815712       0.500628           312328
# 2                  313887            4.649125       0.500648           312987
# 3                  313781            3.070116       0.501055           311975
# 4                  312680            2.722560       0.500813           312638
# ..                    ...                 ...            ...              ...
# 315                 31229            3.386788       0.503172            30959
# 316                 31010            1.949145       0.497389            30828
# 317                 31193            2.729875       0.500090            31166
# 318                 31251            2.828389       0.499154            30922
# 319                 31148            3.598016       0.497844            31506
#
#      inverted_nans  random_inverted_mean  random_inverted_counts  \
# 0         1.574499              0.500606                  312067
# 1         2.755004              0.500405                  313007
# 2         0.928809              0.499787                  312781
# 3         2.509480              0.499929                  312231
# 4         2.855417              0.500488                  312963
# ..             ...                   ...                     ...
# 315       2.191964              0.501660                   31050
# 316       3.653043              0.499252                   31216
# 317       2.852435              0.503592                   31306
# 318       2.748464              0.496254                   31419
# 319       1.986225              0.499833                   31261
#
#      random_inverted_nans  window    thr
# 0                1.577302       2  0.010
# 1                2.757782       2  0.010
# 2                0.930415       2  0.010
# 3                2.508777       2  0.010
# 4                2.854468       2  0.010
# ..                    ...     ...    ...
# 315              2.188019       3  0.001
# 316              3.627883       3  0.001
# 317              2.842810       3  0.001
# 318              2.740444       3  0.001
# 319              1.968747       3  0.001
#
# [320 rows x 14 columns]

# %%
with open('r1.pickle','rb') as file:
    results = pickle.load(file)

# %%
results1 = [x for x in results if type(x)==dict]

# %%
results1 = pd.DataFrame(results1)

# %%
results1
# Out:
#          mean  counts  window    thr
# 0    0.500235  314154       2  0.010
# 1    0.500480  313777       2  0.010
# 2    0.500163  312978       2  0.010
# 3    0.501219  313177       2  0.010
# 4    0.500871  312021       2  0.010
# ..        ...     ...     ...    ...
# 155  0.500234   31100       3  0.001
# 156  0.499413   31508       3  0.001
# 157  0.500532   31052       3  0.001
# 158  0.495916   31294       3  0.001
# 159  0.502033   31354       3  0.001
#
# [160 rows x 4 columns]

# %%
import scipy 

means = results1[(results1.window==2)&(results1.thr==0.01)]

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h
# print(means)
mean_confidence_interval(means)
# Out:
# (0.5004947108789995, 0.5003041563439701, 0.500685265414029)

# %%
np.nanmean(data.iloc[3:])
# Out:
# 72916056.72138348

# %%
data.iloc[3:]
# Out:
#             mean       counts  window
# thr
# 0.0075  0.500459  234921.3750     2.0
# 0.0100  0.500495  313092.6875     2.0

# %%
fig, axs = plt.subplots(1, 2,figsize=(15,15))
data = results1[(results1.window==2)].groupby('thr').mean()

axs[0].scatter(data.index, data['mean'], alpha=0.5)
ax.fill_between(q.index, (q['mean']-ci['mean']), (q['mean']+ci['mean']), color='b', alpha=.1)

# %%
def is_out(s):
    return True if s[0]>0.5 or s[1]<0.5 else False

results['ci'] = results.apply(lambda x: proportion_confint(int(x['mean']*x['counts']), x['counts']), axis=1)
results['ci_out'] = results.apply(lambda x: is_out(proportion_confint(int(x['mean']*x['counts']), x['counts'])), axis=1)

# %%
results[results.ci_out==True]
# Out:
#          mean   counts  window    thr  \
# 17   0.500568  3122247       2  0.100
# 203  0.501820   311391       3  0.010
# 279  0.502729   156902       3  0.005
# 287  0.502516   156917       3  0.005
#
#                                            ci  ci_out
# 17   (0.5000134148847756, 0.5011226259217333)    True
# 203  (0.5000631038129972, 0.5035754085396398)    True
# 279    (0.5002538304825795, 0.50520180424483)    True
# 287  (0.5000401937711982, 0.5049879421222996)    True

# %%
results.groupby(['window','thr']).mean()
# Out:
#                   mean        counts
# window thr
# 1      0.001  0.500286  3.160469e+04
#        0.005  0.500405  1.595059e+05
#        0.010  0.500171  3.124221e+05
#        0.050  0.500165  1.593283e+06
#        0.100  0.500133  3.185584e+06
# 2      0.001  0.500232  3.110488e+04
#        0.005  0.500180  1.564245e+05
#        0.010  0.500477  3.127267e+05
#        0.050  0.500164  1.563149e+06
#        0.100  0.500037  3.136326e+06
# 3      0.001  0.500434  3.113531e+04
#        0.005  0.500634  1.561541e+05
#        0.010  0.500184  3.124885e+05
#        0.050  0.500022  1.562182e+06
#        0.100  0.500008  3.127931e+06
# 4      0.001  0.500846  3.105769e+04
#        0.005  0.499948  1.559560e+05
#        0.010  0.500095  3.123129e+05
#        0.050  0.500159  1.563406e+06
#        0.100  0.500022  3.128029e+06
# 5      0.001  0.501993  3.114838e+04
#        0.005  0.500127  1.562668e+05
#        0.010  0.500297  3.123676e+05
#        0.050  0.500098  1.563379e+06
#        0.100  0.500004  3.127933e+06
